# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn-whitegrid')
pd.set_option('display.max_rows', None)
raw = pd.read_csv('./data/winemag-data_first150k.csv')

review = raw.copy(deep=True).drop('Unnamed: 0', axis=1)
review.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %% [markdown]
# The data consists of 10 fields:
#
# - *Points*: the number of points WineEnthusiast rated the wine on a scale of 1-100 (though they say they only post reviews for wines that score >=80)
# - *Title*: the title of the wine review, which often contains the vintage if you're interested in extracting that feature
# - *Variety*: the type of grapes used to make the wine (ie Pinot Noir)
# - *Description*: a few sentences from a sommelier describing the wine's taste, smell, look, feel, etc.
# - *Country*: the country that the wine is from
# - *Province*: the province or state that the wine is from
# - *Region 1*: the wine growing area in a province or state (ie Napa)
# - *Region 2*: sometimes there are more specific regions specified within a wine growing area (ie Rutherford inside the Napa Valley), but this value can sometimes be blank
# - *Winery*: the winery that made the wine
# - *Designation*: the vineyard within the winery where the grapes that made the wine are from
# - *Price*: the cost for a bottle of the wine
# - *Taster Name*: name of the person who tasted and reviewed the wine
# - *Taster Twitter Handle*: Twitter handle for the person who tasted ane reviewed the wine

# %%
review.info() # (150930, 10)
total_sample = len(review.index)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 10 columns):
# country        150925 non-null object
# description    150930 non-null object
# designation    105195 non-null object
# points         150930 non-null int64
# price          137235 non-null float64
# province       150925 non-null object
# region_1       125870 non-null object
# region_2       60953 non-null object
# variety        150930 non-null object
# winery         150930 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 11.5+ MB

# %%
review.describe()
# Out:
#               points          price
# count  150930.000000  137235.000000
# mean       87.888418      33.131482
# std         3.222392      36.322536
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %%
# Features has missing values
feat = list()
missing_num = list()

for col in review.columns:
    if True in review[col].isnull().values:
        feat.append(col)
        number = review[col].isnull().sum()
        missing_num.append(number)
        print(col, 'has {} missing value'.format(number), \
              ', with {0:.4f}% missing rate'.format(number / total_sample * 100))

x, y = feat, missing_num
plt.rcParams.update({'font.size': 15})
plt.figure(figsize=(9, 5))
plt.bar(x, y, alpha=1)
plt.xlabel('Features', fontsize=15)
plt.ylabel('Missing number', fontsize=15)
plt.title('Missing Value')
# Out:
# country has 5 missing value , with 0.0033% missing rate
# designation has 45735 missing value , with 30.3021% missing rate
# price has 13695 missing value , with 9.0737% missing rate
# province has 5 missing value , with 0.0033% missing rate
# region_1 has 25060 missing value , with 16.6037% missing rate
# region_2 has 89977 missing value , with 59.6151% missing rate
# Text(0.5, 1.0, 'Missing Value')

# %%
# Descriptiom
for i in range(len(review.index)):
    review.loc[i, 'description'] = len(review.loc[i, 'description'])
review.head()
# Out:
#   country  description                           designation  points  price  \
# 0      US          355                     Martha's Vineyard      96  235.0
# 1   Spain          318  Carodorum Selección Especial Reserva      96  110.0
# 2      US          280         Special Selected Late Harvest      96   90.0
# 3      US          386                               Reserve      96   65.0
# 4  France          376                            La Brûlade      95   66.0
#
#          province           region_1           region_2             variety  \
# 0      California        Napa Valley               Napa  Cabernet Sauvignon
# 1  Northern Spain               Toro                NaN       Tinta de Toro
# 2      California     Knights Valley             Sonoma     Sauvignon Blanc
# 3          Oregon  Willamette Valley  Willamette Valley          Pinot Noir
# 4        Provence             Bandol                NaN  Provence red blend
#
#                     winery
# ...

# %%
# Country
countries = review.country.unique() 
countries
# Out:
# array(['US', 'Spain', 'France', 'Italy', 'New Zealand', 'Bulgaria',
#        'Argentina', 'Australia', 'Portugal', 'Israel', 'South Africa',
#        'Greece', 'Chile', 'Morocco', 'Romania', 'Germany', 'Canada',
#        'Moldova', 'Hungary', 'Austria', 'Croatia', 'Slovenia', nan,
#        'India', 'Turkey', 'Macedonia', 'Lebanon', 'Serbia', 'Uruguay',
#        'Switzerland', 'Albania', 'Bosnia and Herzegovina', 'Brazil',
#        'Cyprus', 'Lithuania', 'Japan', 'China', 'South Korea', 'Ukraine',
#        'England', 'Mexico', 'Georgia', 'Montenegro', 'Luxembourg',
#        'Slovakia', 'Czech Republic', 'Egypt', 'Tunisia', 'US-France'],
#       dtype=object)

# %%
review.country.isnull().sum()
# Out:
# 5

# %%
review.loc[pd.isnull(review.country)]
# Out:
#        country                                        description  \
# 1133       NaN  Delicate white flowers and a spin of lemon pee...
# 1440       NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 68226      NaN  From first sniff to last, the nose never makes...
# 113016     NaN  From first sniff to last, the nose never makes...
# 135696     NaN  From first sniff to last, the nose never makes...
#
#          designation  points  price province region_1 region_2     variety  \
# 1133       Askitikos      90   17.0      NaN      NaN      NaN   Assyrtiko
# 1440            Shah      90   30.0      NaN      NaN      NaN   Red Blend
# 68226   Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 113016  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 135696  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
#
#            winery
# 1133     Tsililis
# 1440    Büyülübağ
# 68226     Chilcas
# 113016    Chilcas
# 135696    Chilcas

# %%
# encoding Country
print('Country number:', len(countries))
country_dict = dict()
review.loc[pd.isnull(review['country']), ['country']] = 'Beijing'
# null_ID = review[pd.isnull(review['country'])].index
# print(null_ID)
# notnull_ID = list(set(review.index) - set(null_ID))
# tmp_review = review.iloc[notnull_ID]
# countries = tmp_review['country'].unique()
countries = review.country.unique()
for i in range(len(countries)):
    country_dict[countries[i]] = i

for c in countries:
    review['country'] = review['country'].replace(c, country_dict[c])

review.head()
# review.loc[review['country'] == -1]
# Out:
# Country number: 49
#    country  description                           designation  points  price  \
# 0        0          355                     Martha's Vineyard      96  235.0
# 1        1          318  Carodorum Selección Especial Reserva      96  110.0
# 2        0          280         Special Selected Late Harvest      96   90.0
# 3        0          386                               Reserve      96   65.0
# 4        2          376                            La Brûlade      95   66.0
#
#          province           region_1           region_2             variety  \
# 0      California        Napa Valley               Napa  Cabernet Sauvignon
# 1  Northern Spain               Toro                NaN       Tinta de Toro
# 2      California     Knights Valley             Sonoma     Sauvignon Blanc
# 3          Oregon  Willamette Valley  Willamette Valley          Pinot Noir
# 4        Provence             Bandol                NaN  Provence red blend
#
# ...

# %%
# Designation
des = review.designation.unique()
len(des)
# Out:
# 30622

# %%
review.designation.isnull().sum()
# Out:
# 45735

# %%
review.loc[pd.isnull(review.designation)].head()
# Out:
#     country  description designation  points  price      province  \
# 36        2          169         NaN      90   60.0  Rhône Valley
# 37        3          265         NaN      90   29.0       Tuscany
# 38        3          277         NaN      90   23.0       Tuscany
# 48        3          323         NaN      90   50.0       Tuscany
# 49        0          177         NaN      90   40.0    Washington
#
#                         region_1         region_2                  variety  \
# 36           Châteauneuf-du-Pape              NaN  Rhône-style White Blend
# 37  Vino Nobile di Montepulciano              NaN               Sangiovese
# 38              Chianti Classico              NaN               Sangiovese
# 48        Brunello di Montalcino              NaN               Sangiovese
# 49                  Red Mountain  Columbia Valley       Cabernet Sauvignon
#
#                           winery
# 36  Clos de L'Oratoire des Papes
# 37                    Avignonesi
# ...

# %%
# encoding designation
null_ID = review[pd.isnull(review['designation'])].index
notnull_ID = list(set(review.index) - set(null_ID))
des = review.iloc[notnull_ID]
des = des['designation'].unique()
# print(des)
des_dict = dict()
for i in range(len(des)):
    des_dict[des[i]] = i
# print(des_dict)
for d in des:
    review['designation'] = review['designation'].replace(d, des_dict[d])
review.loc[null_ID, ['designation']] = -1
review.head(10)
# Out:
#    country  description  designation  points  price        province  \
# 0        0          355          0.0      96  235.0      California
# 1        1          318          1.0      96  110.0  Northern Spain
# 2        0          280          2.0      96   90.0      California
# 3        0          386          3.0      96   65.0          Oregon
# 4        2          376          4.0      95   66.0        Provence
# 5        1          315          5.0      95   73.0  Northern Spain
# 6        1          319          6.0      95   65.0  Northern Spain
# 7        1          357          7.0      95  110.0  Northern Spain
# 8        0          298          8.0      95   65.0          Oregon
# 9        0          307          9.0      95   60.0      California
#
#              region_1           region_2             variety  \
# 0         Napa Valley               Napa  Cabernet Sauvignon
# 1                Toro                NaN       Tinta de Toro
# ...

# %%
# Points
p = review.points.unique()
p # no missing point
# Out:
# array([ 96,  95,  94,  90,  91,  86,  89,  88,  87,  93,  92,  85,  84,
#         83,  82,  81, 100,  99,  98,  97,  80])

# %%
(review['points'] == 100).sum()
# Out:
# 24

# %%
review['points'].describe()
# Out:
# count    150930.000000
# mean         87.888418
# std           3.222392
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          90.000000
# max         100.000000
# Name: points, dtype: float64

# %%
plt.figure(figsize=(7, 7))
plt.hist(review['points'],  density=False, alpha=1,
        histtype='bar', color='steelblue', 
        edgecolor='k')
plt.xlabel('Points')
plt.ylabel('Number')
plt.title('Point Distribution')
# Out:
# Text(0.5, 1.0, 'Point Distribution')

# %%
# encoding points
point_mean = review['points'].mean()
review.loc[(review['points'] > 96) & (review['points'] <= 100), 'points'] = 1
review.loc[(review['points'] > 92) & (review['points'] <= 96), 'points'] = 2
review.loc[(review['points'] > 88) & (review['points'] <= 92), 'points'] = 3
review.loc[(review['points'] > 84) & (review['points'] <= 88), 'points'] = 4
review.loc[(review['points'] >= 80) & (review['points'] <= 84), 'points'] = 5
review.head(10)
# Out:
#    country  description  designation  points  price        province  \
# 0        0          355          0.0       2  235.0      California
# 1        1          318          1.0       2  110.0  Northern Spain
# 2        0          280          2.0       2   90.0      California
# 3        0          386          3.0       2   65.0          Oregon
# 4        2          376          4.0       2   66.0        Provence
# 5        1          315          5.0       2   73.0  Northern Spain
# 6        1          319          6.0       2   65.0  Northern Spain
# 7        1          357          7.0       2  110.0  Northern Spain
# 8        0          298          8.0       2   65.0          Oregon
# 9        0          307          9.0       2   60.0      California
#
#              region_1           region_2             variety  \
# 0         Napa Valley               Napa  Cabernet Sauvignon
# 1                Toro                NaN       Tinta de Toro
# ...

# %%
# Price
price_counts = review.price.value_counts()
price_counts.head(10)
# Out:
# 20.0    7860
# 15.0    7056
# 18.0    5988
# 25.0    5955
# 30.0    5449
# 10.0    5255
# 12.0    4950
# 13.0    4479
# 16.0    4273
# 35.0    4194
# Name: price, dtype: int64

# %%
pd.isnull(review.price).sum()
# Out:
# 13695

# %%
review['price'].unique()[: 40]
# Out:
# array([235., 110.,  90.,  65.,  66.,  73.,  60.,  80.,  48., 185., 325.,
#        290.,  75.,  24.,  79., 220.,  45.,  57.,  62., 105.,  15.,  37.,
#         nan,  22.,  42., 135.,  29.,  23.,  17.,  26.,  55.,  39.,  69.,
#         30.,  50.,  40., 100.,  68.,  28.,  18.])

# %%
review['price'].describe()
# Out:
# count    137235.000000
# mean         33.131482
# std          36.322536
# min           4.000000
# 25%          16.000000
# 50%          24.000000
# 75%          40.000000
# max        2300.000000
# Name: price, dtype: float64

# %%
review.loc[pd.isnull(review.price)].head()
# Out:
#      country  description  designation  points  price      province  \
# 32         3          293         31.0       3    NaN       Tuscany
# 56         2          239         45.0       3    NaN  Loire Valley
# 72         3          276         57.0       3    NaN      Piedmont
# 82         3          290         64.0       3    NaN      Piedmont
# 116        1          207         88.0       4    NaN       Levante
#
#                    region_1 region_2          variety             winery
# 32   Brunello di Montalcino      NaN       Sangiovese    Abbadia Ardenga
# 56                 Sancerre      NaN  Sauvignon Blanc   Domaine Vacheron
# 72                   Barolo      NaN         Nebbiolo    Silvano Bolmida
# 82                    Roero      NaN         Nebbiolo              Ceste
# 116                 Jumilla      NaN       Monastrell  Casa de la Ermita

# %%
review['price'] = review['price'].apply(lambda x: -20.0 if pd.isnull(x) else x)

plt.figure(figsize=(9, 6))
plt.hist(review['price'], alpha=1, color='r',
         histtype='bar', density=False,
         bins=1000)
plt.axis([-30, 280, 0, 16000])
plt.xlabel('Price')
plt.ylabel('Number')
plt.title('Price Distribution')
# list(review[review['price'] > 200].index)
# Out:
# Text(0.5, 1.0, 'Price Distribution')

# %%
# encoding price
# min(except -20): 4, max: 2300
null_ID = review[pd.isnull(review['price'])].index
review.loc[null_ID, ['price']] = -1
# notnull_ID = list(set(review.index) - set(null_ID))
# temp_review = review.iloc[notnull_ID]
# srt = sorted(set(temp_review['price'].values))
# interval = np.ceil((srt[-1] - srt[1]) / 100) # 23
price = review['price'].unique()
# print(price)
for i in price:
    review['price'] = review['price'].replace(i, np.floor(i / 100) + 1)

review.head(10)
# Out:
#    country  description  designation  points  price        province  \
# 0        0          355          0.0       2    3.0      California
# 1        1          318          1.0       2    2.0  Northern Spain
# 2        0          280          2.0       2    1.0      California
# 3        0          386          3.0       2    1.0          Oregon
# 4        2          376          4.0       2    1.0        Provence
# 5        1          315          5.0       2    1.0  Northern Spain
# 6        1          319          6.0       2    1.0  Northern Spain
# 7        1          357          7.0       2    2.0  Northern Spain
# 8        0          298          8.0       2    1.0          Oregon
# 9        0          307          9.0       2    1.0      California
#
#              region_1           region_2             variety  \
# 0         Napa Valley               Napa  Cabernet Sauvignon
# 1                Toro                NaN       Tinta de Toro
# ...

# %%
# Province
prov = review.province.unique()
len(prov)
# Out:
# 456

# %%
pd.isnull(review.province).sum()
# Out:
# 5

# %%
prov[: 40]
# Out:
# array(['California', 'Northern Spain', 'Oregon', 'Provence',
#        'Northeastern Italy', 'Southwest France', 'Kumeu', 'Washington',
#        'Bulgaria', 'Tuscany', 'France Other', 'Rhône Valley', 'Galicia',
#        'Andalucia', 'Idaho', 'Burgundy', 'Loire Valley', 'New York',
#        'Mendoza Province', 'Victoria', 'Alentejano', 'Piedmont',
#        'Alentejo', 'Champagne', 'Upper Galilee', 'Beira Atlantico',
#        'Veneto', 'Douro', 'Tejo', 'Stellenbosch', 'Levante',
#        'Sicily & Sardinia', 'Southern Italy', 'Languedoc-Roussillon',
#        'Bordeaux', 'Atalanti Valley', 'Catalonia', 'Santorini', 'Florina',
#        'Marchigue'], dtype=object)

# %%
review.loc[pd.isnull(review.province)]
# Out:
#         country  description  designation  points  price province region_1  \
# 1133         22          260        729.0       3    1.0      NaN      NaN
# 1440         22          385        902.0       3    1.0      NaN      NaN
# 68226        22          232      22334.0       5    1.0      NaN      NaN
# 113016       22          232      22334.0       5    1.0      NaN      NaN
# 135696       22          232      22334.0       5    1.0      NaN      NaN
#
#        region_2     variety     winery
# 1133        NaN   Assyrtiko   Tsililis
# 1440        NaN   Red Blend  Büyülübağ
# 68226       NaN  Pinot Noir    Chilcas
# 113016      NaN  Pinot Noir    Chilcas
# 135696      NaN  Pinot Noir    Chilcas

# %%
# encoding province
review.loc[pd.isnull(review['province']), ['province']] = 'Beijing'

"""
prov_dict = dict()
for p in range(len(prov)):
    prov_dict[prov[p]] = p
for p in prov:
    review['province'] = review['province'].replace(p, prov_dict[p])
review.head()
"""
review.loc[review['province'] == 'Beijing']
# Out:
#         country  description  designation  points  price province region_1  \
# 1133         22          260        729.0       3    1.0  Beijing      NaN
# 1440         22          385        902.0       3    1.0  Beijing      NaN
# 68226        22          232      22334.0       5    1.0  Beijing      NaN
# 113016       22          232      22334.0       5    1.0  Beijing      NaN
# 135696       22          232      22334.0       5    1.0  Beijing      NaN
#
#        region_2     variety     winery
# 1133        NaN   Assyrtiko   Tsililis
# 1440        NaN   Red Blend  Büyülübağ
# 68226       NaN  Pinot Noir    Chilcas
# 113016      NaN  Pinot Noir    Chilcas
# 135696      NaN  Pinot Noir    Chilcas

# %%
# review.to_csv('./data/temp.csv')

# %%
# region_1
region1 = review.region_1.unique()
region1
# Out:
# array(['Napa Valley', 'Toro', 'Knights Valley', ..., 'Listrac',
#        'St.-Amour', 'Coteaux du Tricastin'], dtype=object)

# %%
len(region1)
# Out:
# 1237

# %%
review.region_1.isnull().sum()
# Out:
# 25060

# %%
review.loc[pd.isnull(review['region_1'])].head()
# Out:
#     country  description  designation  points  price    province region_1  \
# 25        4          215         24.0       2    1.0       Kumeu      NaN
# 30        5          237         29.0       3    1.0    Bulgaria      NaN
# 42        0          218         37.0       3    1.0       Idaho      NaN
# 64        8          281         -1.0       3    1.0  Alentejano      NaN
# 74        8          226         58.0       3    1.0    Alentejo      NaN
#
#    region_2         variety                      winery
# 25      NaN      Chardonnay                 Kumeu River
# 30      NaN          Mavrud                Villa Melnik
# 42      NaN    Petite Sirah                      Huston
# 64      NaN  Portuguese Red            Herdade do Rocim
# 74      NaN  Portuguese Red  Adega Cooperativa de Borba

# %%
# region_2
region2 = review['region_2'].unique()
region2
# Out:
# array(['Napa', nan, 'Sonoma', 'Willamette Valley', 'Central Coast',
#        'Columbia Valley', 'Finger Lakes', 'California Other',
#        'Mendocino/Lake Counties', 'South Coast', 'Central Valley',
#        'New York Other', 'Sierra Foothills', 'Southern Oregon',
#        'Oregon Other', 'Napa-Sonoma', 'North Coast', 'Washington Other',
#        'Long Island'], dtype=object)

# %%
len(region2)
# Out:
# 19

# %%
pd.isnull(review['region_2']).sum()
# Out:
# 89977

# %%
review.loc[review['region_2'].isnull()].head()
# Out:
#    country  description  designation  points  price        province region_1  \
# 1        1          318          1.0       2    2.0  Northern Spain     Toro
# 4        2          376          4.0       2    1.0        Provence   Bandol
# 5        1          315          5.0       2    1.0  Northern Spain     Toro
# 6        1          319          6.0       2    1.0  Northern Spain     Toro
# 7        1          357          7.0       2    2.0  Northern Spain     Toro
#
#   region_2             variety                   winery
# 1      NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 4      NaN  Provence red blend     Domaine de la Bégude
# 5      NaN       Tinta de Toro                Numanthia
# 6      NaN       Tinta de Toro                 Maurodos
# 7      NaN       Tinta de Toro  Bodega Carmen Rodríguez

# %%
# merge region_1 and region_2 to new feature region
review.loc[pd.isnull(review['region_2']), ['region_2']] = ''
review.loc[pd.isnull(review['region_1']), ['region_1']] = ''
review.loc[:, 'region'] = review.loc[:, 'province'] + ' ' + review.loc[:, 'region_1'] + ' ' + review.loc[:, 'region_2']
# review.loc[:, 'region'] = review.loc[:, 'region_1'] + ' ' + review.loc[:, 'region_2']
review.head()
# Out:
#    country  description  designation  points  price        province  \
# 0        0          355          0.0       2    3.0      California
# 1        1          318          1.0       2    2.0  Northern Spain
# 2        0          280          2.0       2    1.0      California
# 3        0          386          3.0       2    1.0          Oregon
# 4        2          376          4.0       2    1.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                          Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                     Provence red blend
#
#                     winery                                      region
# 0                    Heitz                 California Napa Valley Napa
# ...

# %%
# encoding region
"""
null_ID = review[pd.isnull(review['region_1'])].index
new_ID = list(set(review.index) - set(null_ID))
review = review.iloc[new_ID]
"""
review.region.head()
# Out:
# 0                   California Napa Valley Napa
# 1                          Northern Spain Toro
# 2              California Knights Valley Sonoma
# 3    Oregon Willamette Valley Willamette Valley
# 4                              Provence Bandol
# Name: region, dtype: object

# %%
region = review['region'].unique()
print(len(region))
region_dict = dict()
for r in range(len(region)):
    region_dict[region[r]] = r
for reg in region:
    review['region'] = review['region'].replace(reg, region_dict[reg])
    # review.loc[review['region'] == reg, ['region']] = region_dict[reg]
review.head()
# Out:
# 1638
#    country  description  designation  points  price        province  \
# 0        0          355          0.0       2    3.0      California
# 1        1          318          1.0       2    2.0  Northern Spain
# 2        0          280          2.0       2    1.0      California
# 3        0          386          3.0       2    1.0          Oregon
# 4        2          376          4.0       2    1.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                          Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                     Provence red blend
#
#                     winery  region
# 0                    Heitz       0
# 1  Bodega Carmen Rodríguez       1
# 2                 Macauley       2
# 3                    Ponzi       3
# ...

# %%
# Variety 
variety = review['variety'].unique()
len(variety)
# Out:
# 632

# %%
variety[: 20]
# Out:
# array(['Cabernet Sauvignon', 'Tinta de Toro', 'Sauvignon Blanc',
#        'Pinot Noir', 'Provence red blend', 'Friulano', 'Tannat',
#        'Chardonnay', 'Tempranillo', 'Malbec', 'Rosé', 'Tempranillo Blend',
#        'Syrah', 'Mavrud', 'Sangiovese', 'Sparkling Blend',
#        'Rhône-style White Blend', 'Red Blend', 'Mencía', 'Palomino'],
#       dtype=object)

# %%
# encoding variety
variety_dict = dict()
for v in range(len(variety)):
    variety_dict[variety[v]] = v
for var in variety:
    review['variety'] = review['variety'].replace(var, variety_dict[var])
review.head()
# Out:
#    country  description  designation  points  price        province  \
# 0        0          355          0.0       2    3.0      California
# 1        1          318          1.0       2    2.0  Northern Spain
# 2        0          280          2.0       2    1.0      California
# 3        0          386          3.0       2    1.0          Oregon
# 4        2          376          4.0       2    1.0        Provence
#
#             region_1           region_2  variety                   winery  \
# 0        Napa Valley               Napa        0                    Heitz
# 1               Toro                           1  Bodega Carmen Rodríguez
# 2     Knights Valley             Sonoma        2                 Macauley
# 3  Willamette Valley  Willamette Valley        3                    Ponzi
# 4             Bandol                           4     Domaine de la Bégude
#
#    region
# 0       0
# 1       1
# 2       2
# 3       3
# 4       4

# %%
# Winery
winery = review['winery'].unique()
len(winery)
# Out:
# 14810

# %%
winery[: 20]
# Out:
# array(['Heitz', 'Bodega Carmen Rodríguez', 'Macauley', 'Ponzi',
#        'Domaine de la Bégude', 'Numanthia', 'Maurodos', 'Bergström',
#        'Blue Farm', 'Borgo del Tiglio', 'Patricia Green Cellars',
#        'Vignobles Brumont', 'Domaine Serene', 'Hall', 'Valduero',
#        'Château Lagrézette', 'Gary Farrell', 'Muga', 'Center of Effort',
#        'Comartin'], dtype=object)

# %%
# encoding winery
winery_dict = dict()
for w in range(len(winery)):
    winery_dict[winery[w]] = w
for win in winery:
    review['winery'] = review['winery'].replace(win, winery_dict[win])
review.head()
# Out:
#    country  description  designation  points  price        province  \
# 0        0          355          0.0       2    3.0      California
# 1        1          318          1.0       2    2.0  Northern Spain
# 2        0          280          2.0       2    1.0      California
# 3        0          386          3.0       2    1.0          Oregon
# 4        2          376          4.0       2    1.0        Provence
#
#             region_1           region_2  variety  winery  region
# 0        Napa Valley               Napa        0       0       0
# 1               Toro                           1       1       1
# 2     Knights Valley             Sonoma        2       2       2
# 3  Willamette Valley  Willamette Valley        3       3       3
# 4             Bandol                           4       4       4

# %%
review.shape
# Out:
# (150930, 11)

# %%
review.to_csv('./data/wine_vector_2.csv')
